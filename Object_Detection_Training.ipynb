# %%
# !pip install ultralytics

# %%
# !unzip /content/DeteksiBuku.v3i.yolov8.zip -d /content/DeteksiBuku
# Out:
# Archive:  /content/DeteksiBuku.v3i.yolov8.zip
# replace /content/DeteksiBuku/README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/DeteksiBuku/README.dataset.txt
#   inflating: /content/DeteksiBuku/README.roboflow.txt
#   inflating: /content/DeteksiBuku/data.yaml
#  extracting: /content/DeteksiBuku/test/images/WhatsApp-Image-2026-01-19-at-13-32-55-2-_jpeg.rf.aa171b4145ff7d926bd9b91b77d644ef.jpg
#  extracting: /content/DeteksiBuku/test/images/WhatsApp-Image-2026-01-19-at-13-32-55_jpeg.rf.ca1a1cebc745ff3c40db9a0c182dbee6.jpg
#  extracting: /content/DeteksiBuku/test/labels/WhatsApp-Image-2026-01-19-at-13-32-55-2-_jpeg.rf.aa171b4145ff7d926bd9b91b77d644ef.txt
#   inflating: /content/DeteksiBuku/test/labels/WhatsApp-Image-2026-01-19-at-13-32-55_jpeg.rf.ca1a1cebc745ff3c40db9a0c182dbee6.txt
#  extracting: /content/DeteksiBuku/train/images/WhatsApp-Image-2026-01-19-at-13-32-55-3-_jpeg.rf.99632f7d3563c382d54e451700aece0f.jpg
# ...

# %%
# !yolo detect train data = /content/DeteksiBuku/data.yaml
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !yolo detect predict model = /content/runs/detect/train/weights/best.pt source = 'https://cdn.gramedia.com/uploads/products/95ob5m98ur.jpg'
# Out:
# Ultralytics 8.4.6 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO26n summary (fused): 122 layers, 2,375,811 parameters, 0 gradients, 5.2 GFLOPs
#
# ...
# image 1/1 /content/95ob5m98ur.jpg: 640x448 (no detections), 162.9ms
# Speed: 4.2ms preprocess, 162.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to /content/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
